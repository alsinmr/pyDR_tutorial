# %% [markdown]
# # <font color="maroon">Chapter 5: Anatomy of pyDIFRATE</font>

# %% [markdown]
# pyDR uses extensive application of object-oriented programming in order to streamline detector analysis and ensure that data is correctly treated. The central object in pyDR is the 'data' object, which naturally contains dynamics data, but also contains all the other information about that data, including confidence on the data, the sensitivity of the experiments in the data, detector objects used to process the data, labels for the data, and information about the experiments or detectors. In case of processes data, there is additional information about the fitting and the source data, in some cases. It also contains functions for fitting the data, and additionally displaying it.

# %%
# %cd ..
import pyDR
# Out:
# /Users/albertsmith/Documents/GitHub

# %%
proj=pyDR.Project('GHSR_archive/Projects/backboneHN/')

# %%
proj[0].sens.plot_rhoz()

# %% [markdown]
# proj[0]

# %%
for field in dir(proj[0]):
    if '__' not in field and field[0]!='_':
        print(field)
# Out:
# AIC
# AICc
# R
# Rc
# Rstd
# S2
# S2c
# S2std
# chi2
# chi2red
# chimera
# del_data_pt
# del_exp
# details
# detect
# fit
# info
# label
# movies
# n_data_pts
# ne
# nglview
# opt2dist
# plot
# plot_fit
# project
# save
# select
# sens
# source
# src_data
# title
# vars

# %%
proj[0].vars
# Out:
# {}

# %%
proj[0].n_data_pts
# Out:
# 295

# %%
len(proj[0])
# Out:
# 295

# %%
source=proj[0].source

# %%
dir(source)
# Out:
# ['Type',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_src_data',
#  '_status',
#  '_title',
#  'additional_info',
#  'default_save_location',
#  'details',
#  'filename',
#  'n_det',
#  'original_file',
#  'project',
#  'saved_filename',
#  'select',
#  'short_file',
#  'src_data',
#  'status',
#  'title',
#  'topo',
#  'traj']

# %%
source.traj
# Out:
# ['/Users/albertsmith/Documents/GitHub/GHSR_archive/Projects/backboneHN/pdbs/WT-apo_run1_just_protein.pdb']

# %%
select=proj[0].select

# %%
select.molsys.topo
# Out:
# '/Users/albertsmith/Documents/GitHub/GHSR_archive/Projects/backboneHN/pdbs/WT-apo_run1_just_protein.pdb'

# %%
len(select)
# Out:
# 295

# %%
dir(select)
# Out:
# ['__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_hash',
#  '_label',
#  '_mdmode',
#  '_project',
#  '_repr_sel',
#  '_sel1',
#  '_sel2',
#  'box',
#  'chimera',
#  'clear_sel',
#  'compare',
#  'copy',
#  'del_sel',
#  'details',
#  'label',
#  'molsys',
#  'pos',
#  'project',
#  'repr_sel',
#  'sel1',
#  'sel2',
#  'select_bond',
#  'set_label',
#  'set_selection',
#  'traj',
#  'uni',
#  'v']

# %%
dir(source)
# Out:
# ['Type',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_src_data',
#  '_status',
#  '_title',
#  'additional_info',
#  'default_save_location',
#  'details',
#  'filename',
#  'n_det',
#  'original_file',
#  'project',
#  'saved_filename',
#  'select',
#  'short_file',
#  'src_data',
#  'status',
#  'title',
#  'topo',
#  'traj']

# %%
source.original_file
# Out:
# ['/work/public/ghrelin-receptor/WT-apo_run1_0.1ns_just_protein.xtc']

# %%
sens=proj[0].sens

# %%
dir(sens)
# Out:
# ['ApplyNorm',
#  'Detector',
#  'R0',
#  'R2ex',
#  'SVD',
#  'T',
#  '_Detector__locked',
#  '_Detector__r',
#  '_Sens__index',
#  '_Sens__norm',
#  '_Sens__rho',
#  '_Sens__rhoCSA',
#  '_Sens__z',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bonds',
#  '_hash',
#  '_islocked',
#  '_norm',
#  '_parent',
#  '_rho',
#  '_rhoCSA',
#  '_rho_eff',
#  '_rho_effCSA',
#  '_rhozCSA',
#  '_update_rho',
#  'allowNeg',
#  'append',
#  'copy',
#  'del_exp',
#  'dz',
#  'inclS2',
#  'info',
#  'lock',
#  'match_parent',
# ...

# %%
sens.T

# %%
data=proj[0]

# %%
data.sens.sens.plot_rhoz()

# %%
data._Rc

# %%
dir(proj)
# Out:
# ['Types',
#  '__add__',
#  '__and__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_current_plot',
#  '_directory',
#  '_index',
#  '_ipython_display_',
#  '_ipython_key_completions_',
#  '_subproject',
#  'add_fig',
#  'additional_info',
#  'append_data',
#  'chimera',
#  'clear_memory',
#  'close_fig',
#  'comparable',
#  'current_plot',
#  'data',
#  'detect',
#  'directory',
#  'fig',
#  'filenames',
#  'fit',
#  'info',
#  'modes2bonds',
#  'name',
#  'opt2dist',
#  'parent',
#  'parent_index',
# ...

# %%
fr_obj=pyDR.Frames.FrameObj()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-7aecc1b09cbc> in <module>()
# ----> 1 fr_obj=pyDR.Frames.FrameObj()
#
# ~/Documents/GitHub/pyDR/Frames/eval_fr.py in __init__(self, select, molecule)
#     155     def __init__(self,select=None,molecule=None):
#     156         self.select=copy(select) if select is not None else copy(molecule) #I want to phase out using the name molecule
# --> 157         self.select._mdmode=True
#     158         self.vft=None
#     159         self.vf=list()
#
# AttributeError: 'NoneType' object has no attribute '_mdmode'

# %%
pyDR.Frames.FrameObj.f
